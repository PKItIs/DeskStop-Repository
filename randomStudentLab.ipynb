# %% [markdown]
# <a href="https://colab.research.google.com/github/PKItIs/DeskStop-Repository/blob/main/randomStudentLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import random

def create_groups(csv_filepath, group_size=4):
    """
    Reads student names from a CSV file, creates groups of a specified size,
    and assigns unique techie names to each group.

    Args:
        csv_filepath: Path to the CSV file containing student names.
        group_size: The desired size of each group.

    Returns:
        A list of groups, where each group is a list of student names with a group name.
    """

    try:
        with open(csv_filepath, 'r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            students = [row[0] for row in reader if row]  # Extract student names from the first column

    except FileNotFoundError:
        print(f"Error: File '{csv_filepath}' not found.")
        return []

    num_students = len(students)
    if num_students < group_size:
        print(f"Error: Not enough students for groups of {group_size}")
        return []

    random.shuffle(students)
    groups = []
    techie_names = ["Tech Titans", "Code Crusaders", "Binary Brawlers", "Digital Dominators", "Pixel Pioneers",
                    "Byte Riders", "Algorithm Aces", "Innovation Incubators", "Cyber Squad", "Logic Legends",
                    "Data Dynamos", "Network Ninjas", "Software Savants", "GUI Gurus", "Cloud Commanders"]

    for i in range(0, num_students, group_size):
        group = students[i:min(i + group_size, num_students)]
        if len(group) < group_size and len(groups) > 0:
            # Add remaining students to the last group's members
            groups[-1]['members'].extend(group)
            continue
        group_name = techie_names.pop(random.randrange(len(techie_names))) if techie_names else f"Group {len(groups) + 1}"
        groups.append({"group_name": group_name, "members": group})

    return groups

# Example usage: Replace 'students.csv' with your file's path
# Make sure to upload students.csv to your Colab environment first
groups = create_groups('/content/students.csv')

# Print the groups
for group in groups:
    print(f"Group: {group['group_name']}")
    for student in group['members']:
        print(f"  - {student}")
    print()
# Out:
# Group: Tech Titans
#   - Ankit Verma
#   - Shashank Sharma
#   - Pranay Kadam
#   - Tanishq chopra
#
# Group: Digital Dominators
#   - Grishma Thakare
#   - Roshan Vishwakarma
#   - Sameer rathod
#   - Viketh Hegde
#
# Group: Binary Brawlers
#   - Johnson Pillai
#   - Sudarshan Devadiga
#   - Perni Bharath Raghavendra
#   - Vrish Thadani
#
# Group: Cyber Squad
#   - Ragini Singh
#   - Rayan Satendar Rawat
#   - Atharva Kalekar
#   - RIDDHI SACHIN ZUNJARRAO
#
# Group: Logic Legends
#   - Manas Dange
#   - AYUSH KUMAR
#   - Yash Lal
#   - Kishan Ojha
#
# Group: Pixel Pioneers
#   - Kunal Rathee
#   - Chandresh Dubey
#   - Vijaykarthik T K
#   - Devdarshan Saravanan
#
# Group: Algorithm Aces
#   - Payal kunwar
#   - Shaikh Fayaz Imran
#   - Aditya Nayan Prasad
#   - Arohi Chakote
#
# Group: Code Crusaders
#   - Pranav Kale
#   - Prince Vaviya
#   - Anoop Gupta
#   - Kanishk Trivedi
#
# Group: Software Savants
#   - Dharsan K
#   - Chaitanya Awasthi
#   - Saumya Chinchkhede
#   - Ashutosh Pinkeshwar Jha
#
# Group: Network Ninjas
#   - Siddharth Reddy
#   - Harshal More
#   - Rajneesh Kumar
#   - Kavya Khandelwal
#
# Group: Byte Riders
#   - Sahil Shahaji Kadam
#   - Disha Rao
#   - Ralliyah Rushdah
#   - Meet Alshi
#
# Group: Data Dynamos
#   - Sakshi Pokhriyal
#   - Naman Sethi
#   - Swaraj Wattamwar
#   - Prathamesh swami
#
# Group: GUI Gurus
#   - Arham Khan
#   - Sahil Shah
#   - Naaz Fatema Ahmedi
#   - Antriksh Sandesh Manwadkar
#
# Group: Innovation Incubators
#   - Vamshi Shetty
#   - Yash Khapre
#   - Soumitra Deshpande
#   - Prity Dinesh Prajapati
#
# Group: Cloud Commanders
#   - Chaitanya Shirsat
#   - Kirthish Shetty
#   - Saksham Mishra
#   - Om Pandey
#
# Group: Group 16
#   - Mohammed Rayhaan Shahajan Siledar
#   - Gaurav Kulkarni
#   - Param vinayak Anil singh
#   - Aadarsh Rajendra Deshmukh
#
# Group: Group 17
#   - Mohammed Saif Salmani
#   - Vaibhav Kawde
#   - Fauzan Baig
#   - Bankim Chandra Kamila
#
# Group: Group 18
#   - Shlok Sunil Kamble
#   - Om Madan Sawant
#   - Shlok Vijay Kadam
#   - Aavani Rajesh Perumbessi
#
# Group: Group 19
#   - Pratik Sagvekar
#   - Jason Rajiv Rajan
#   - Sakshi Shingole
#   - Raj koli
#
# Group: Group 20
#   - Saurabh Yadav
#   - Harsh Mishra
#   - Ashmit Suryavanshi
#   - Akash Chauhan
#
# Group: Group 21
#   - Sweta Popat kadam
#   - Rohan Vashisht
#   - Siddhant Jadhav
#   - Sourabh Yadav
#
# Group: Group 22
#   - Soham Ahirrao
#   - Vrutti Nandakishore Patil
#   - Sahil Pandey
#   - Adine Vikash
#
# Group: Group 23
#   - Kinjal Gawali
#   - Rizwan Salmani
#   - Vivek Prasad Addagatla
#   - Shweta Shetty
#
# Group: Group 24
#   - Laxman bhalla Patel
#   - Yash Prakash Parab
#   - Nirab Sadananda Kotian
#   - Zeba Shaikh
#
# Group: Group 25
#   - Krrish Chavan
#   - A.V.N siva Krishna sai
#   - Gandharva Dewan
#   - Tejas Solanki
#
# Group: Group 26
#   - Sujal Warke
#   - Nivedita Biswas
#   - Sanchita Suryawanshi
#   - R Virshin
#
# Group: Group 27
#   - Mayank Negi
#   - Samarth Devadiga
#   - Hitarth Patel
#   - Name
#
# Group: Group 28
#   - Ritesh Sachinrao Jadhav
#   - Jha Ayush Santoshkumar
#   - Abdullah Haque
#   - Utkarsh Harish Satav
#
# Group: Group 29
#   - Ronak Chavhan
#   - Piyush Solanki
#   - Krish Bhartiya
#   - Mandar Salunkhe
#
# Group: Group 30
#   - Arsheel Patel
#   - Atharva Gahine
#   - Adarsh Singh
#   - Amitabh Morey
#
# Group: Group 31
#   - Bhargav Dhole
#   - Aachal Devendra Gupta
#   - Anshuman Atrey
#   - Sarang Gole
#
# Group: Group 32
#   - Aniket Rai
#   - Ashutosh Pankaj Rai
#   - Tejas Mhatre
#   - Shivam Mishra
#
# Group: Group 33
#   - Rohan R Samanta
#   - Vijay Kota
#   - Pratima Vanakhade
#   - PARTH MANOJ SAHANI
#
# Group: Group 34
#   - Nupur Bhoir
#   - Prasad Ganesh Bhad
#   - Om Laxmikant Tellur
#   - Ishaan Khan
#
# Group: Group 35
#   - Sneha Manoj Hande
#   - MOHAMMAD SHAIKH
#   - Ameya Sagwekar
#   - Armaan Mulani
#
# Group: Group 36
#   - Mahesh Rajpurohit
#   - Tripathi Om Ashwin
#   - Manthan Bhosale
#   - Saniya Ajay Kapure
#
# Group: Group 37
#   - Sarthak Prabhakar Kanade
#   - Sarthak Sunil Tajane
#   - Khan rehman
#   - Soham Satish Karandikar
#   - Sayuj Pillai
#   - Aayush Kamble
#   - Aryan Singh
